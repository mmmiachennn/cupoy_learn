# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %% [markdown]
# # 當 lr 越大收斂較快，但設定太大，也很有可能無法

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
# Out:
# '\nwhile previous_step_size > precision and iters < max_iters:\n\n  算法迭代更新\n\nprint("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations\n'

# %%
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations

for lr in lr_lst:
    cur_x = 3
    previous_step_size = 1 #
    iters = 0 #iteration counter
    iters_history = [iters]
    x_history = [cur_x]
    
    while previous_step_size > precision and iters < max_iters:
        prev_x = cur_x #Store current x value in prev_x
        cur_x = cur_x - lr * df(prev_x) #Gradient descent
        previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
        iters = iters + 1 #iteration count
         # Store parameters for plotting
        iters_history.append(iters)
        x_history.append(cur_x)
        
    print(f"{lr} -> Totally iteations: ", iters)
    print(f"{lr} -> The local minimum occurs at", cur_x)

    plt.plot(iters_history, x_history, 'o-', ms=3, lw=1.5, color='black')
    plt.xlabel(r'$iters$', fontsize=16)
    plt.ylabel(r'$x$', fontsize=16)
    plt.show()
# Out:
# 0.1 -> Totally iteations:  66
# 0.1 -> The local minimum occurs at -4.999996786123911
# 0.01 -> Totally iteations:  595
# 0.01 -> The local minimum occurs at -4.9999518490318176
# 0.0001 -> Totally iteations:  10000
# 0.0001 -> The local minimum occurs at -3.917534277778167

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lr_lst = [0.1, 0.01, 0.0001] # Learning rate
previous_step_size = 1 #
iters = 0 #iteration counter

iters_history = [iters]
x_history = [cur_x]

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations

for lr in lr_lst:
    print('123', lr)
    previous_step_size = 1 #
    iters = 0 #iteration counter
    iters_history = [iters]
    x_history = [cur_x]
    while previous_step_size > precision and iters < max_iters:
        prev_x = cur_x #Store current x value in prev_x
        cur_x = cur_x - lr * df(prev_x) #Gradient descent
        previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
        iters = iters + 1 #iteration count
         # Store parameters for plotting
        iters_history.append(iters)
        x_history.append(cur_x)
    print(f"{lr} -> Totally iteations: ", iters)
    print(f"{lr} -> The local minimum occurs at", cur_x)

    plt.plot(iters_history, x_history, 'o-', ms=3, lw=1.5, color='black')
    plt.xlabel(r'$iters$', fontsize=16)
    plt.ylabel(r'$x$', fontsize=16)
    plt.show()
# Out:
# 123 0.1
# 0.1 -> Totally iteations:  66
# 0.1 -> The local minimum occurs at -4.999996786123911
# 123 0.01
# 0.01 -> Totally iteations:  1
# 0.01 -> The local minimum occurs at -4.999996850401433
# 123 0.0001
# 0.0001 -> Totally iteations:  1
# 0.0001 -> The local minimum occurs at -4.999996851031353
